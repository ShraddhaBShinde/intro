# %% [markdown]
# <a href="https://colab.research.google.com/github/ShraddhaBShinde/intro/blob/main/Intern14200322.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Managing Data**

# %% [markdown]
# # Import Dataset as Pandas DataFrame

# %%
import pandas as pd

# %%
df = pd.read_csv('https://github.com/YBI-Foundation/Dataset/raw/main/MPG.csv')

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
mpg = pd.read_csv('/content/MPG.csv')

# %%
mpg.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
excel = pd.read_excel('https://github.com/YBI-Foundation/Dataset/raw/main/Upload%20Excel.xlsx')

# %%
excel.head()
# Out:
#             Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0                 Date         SN       Name     Gender      Class        Age
# 1  2022-04-01 00:00:00          1       Abha          F          1          4
# 2  2022-04-02 00:00:00          2      Akash          M          1        4.1
# 3  2022-04-03 00:00:00          3       Aman       Male          1        4.3
# 4  2022-04-04 00:00:00          4      Amber       Male          2        5.5
#
#   Unnamed: 6 Unnamed: 7       Unnamed: 8
# 0     Weight     Height         Email ID
# 1         24        100   Abha@gmail.com
# 2         28        110  Akash@gmail.com
# 3         30        102   Aman@gmail.com
# 4         31        111  Amber@gmail.com

# %%
excel.tail()
# Out:
#              Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 6   2022-04-06 00:00:00          6      Anita     Female          2
# 7   2022-04-07 00:00:00          7    Anurudh       Male          3
# 8   2022-04-08 00:00:00          8    Aravali     Female          3
# 9   2022-04-09 00:00:00          9       Asha     Female          3
# 10  2022-04-10 00:00:00         10      Awadh       Male        NaN
#
#    Unnamed: 5 Unnamed: 6 Unnamed: 7         Unnamed: 8
# 6         5.7         33        107    Anita@gmail.com
# 7           6         37         98  Anurudh@gmail.com
# 8         6.5         27        106  Aravali@gmail.com
# 9           7         30        114     Asha@gmail.com
# 10        6.8         34        119    Awadh@gmail.com

# %% [markdown]
# # Explore our data

# %%
mpg
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
mpg.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
mpg.tail()
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin             name
# 393          82     usa  ford mustang gl
# 394          82  europe        vw pickup
# 395          82     usa    dodge rampage
# 396          82     usa      ford ranger
# 397          82     usa       chevy s-10

# %%
mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
#  8   name          398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %%
mpg.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model_year      0
# origin          0
# name            0
# dtype: int64

# %%
mpg.notnull().sum()
# Out:
# mpg             398
# cylinders       398
# displacement    398
# horsepower      392
# weight          398
# acceleration    398
# model_year      398
# origin          398
# name            398
# dtype: int64

# %%
mpg.isna().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model_year      0
# origin          0
# name            0
# dtype: int64

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
mpg.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  398.000000    398.000000  392.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.469388  2970.424623
# std      7.815984    1.701004    104.269838   38.491160   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%     29.000000    8.000000    262.000000  126.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year
# count    398.000000  398.000000
# mean      15.568090   76.010050
# std        2.757689    3.697627
# min        8.000000   70.000000
# 25%       13.825000   73.000000
# 50%       15.500000   76.000000
# 75%       17.175000   79.000000
# max       24.800000   82.000000

# %%
mpg.describe(include = 'all')
# Out:
#                mpg   cylinders  displacement  horsepower       weight  \
# count   398.000000  398.000000    398.000000  392.000000   398.000000
# unique         NaN         NaN           NaN         NaN          NaN
# top            NaN         NaN           NaN         NaN          NaN
# freq           NaN         NaN           NaN         NaN          NaN
# mean     23.514573    5.454774    193.425879  104.469388  2970.424623
# std       7.815984    1.701004    104.269838   38.491160   846.841774
# min       9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%      17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%      23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%      29.000000    8.000000    262.000000  126.000000  3608.000000
# max      46.600000    8.000000    455.000000  230.000000  5140.000000
#
#         acceleration  model_year origin        name
# count     398.000000  398.000000    398         398
# ...

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
horsepower = mpg['horsepower']

# %%
horsepower
# Out:
# 0      130.0
# 1      165.0
# 2      150.0
# 3      150.0
# 4      140.0
#        ...
# 393     86.0
# 394     52.0
# 395     84.0
# 396     79.0
# 397     82.0
# Name: horsepower, Length: 398, dtype: float64

# %%
horsepower = mpg[['horsepower']]

# %%
horsepower
# Out:
#      horsepower
# 0         130.0
# 1         165.0
# 2         150.0
# 3         150.0
# 4         140.0
# ..          ...
# 393        86.0
# 394        52.0
# 395        84.0
# 396        79.0
# 397        82.0
#
# [398 rows x 1 columns]

# %%
subset = mpg[['horsepower','weight']]

# %%
subset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   horsepower  392 non-null    float64
#  1   weight      398 non-null    int64
# dtypes: float64(1), int64(1)
# memory usage: 6.3 KB

# %%
subset.describe()
# Out:
#        horsepower       weight
# count  392.000000   398.000000
# mean   104.469388  2970.424623
# std     38.491160   846.841774
# min     46.000000  1613.000000
# 25%     75.000000  2223.750000
# 50%     93.500000  2803.500000
# 75%    126.000000  3608.000000
# max    230.000000  5140.000000

# %% [markdown]
# # .loc

# %%
mpg.loc[  3:8         , 'horsepower': 'origin'                 ]
# Out:
#    horsepower  weight  acceleration  model_year origin
# 3       150.0    3433          12.0          70    usa
# 4       140.0    3449          10.5          70    usa
# 5       198.0    4341          10.0          70    usa
# 6       220.0    4354           9.0          70    usa
# 7       215.0    4312           8.5          70    usa
# 8       225.0    4425          10.0          70    usa

# %%
mpg.loc[  3:8         , [ 'origin', 'horsepower']]
# Out:
#   origin  horsepower
# 3    usa       150.0
# 4    usa       140.0
# 5    usa       198.0
# 6    usa       220.0
# 7    usa       215.0
# 8    usa       225.0

# %%
mpg.loc[  [3,1,90,50,8]         , [ 'origin', 'horsepower']]
# Out:
#     origin  horsepower
# 3      usa       150.0
# 1      usa       165.0
# 90     usa       198.0
# 50  europe        90.0
# 8      usa       225.0

# %%
mpg.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
mpg.loc[mpg['cylinders']==8, :]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 291  19.2          8         267.0       125.0    3605          15.0
# 292  18.5          8         360.0       150.0    3940          13.0
# 298  23.0          8         350.0       125.0    3900          17.4
# 300  23.9          8         260.0        90.0    3420          22.2
# 364  26.6          8         350.0       105.0    3725          19.0
#
#      model_year origin                                  name
# 0            70    usa             chevrolet chevelle malibu
# ...

# %%
mpg.loc[   (mpg['weight']>4500)  & (mpg['mpg']>=13) | (mpg['displacement']>400)    , ['cylinders', 'origin', 'name']]
# Out:
#      cylinders origin                          name
# 5            8    usa              ford galaxie 500
# 6            8    usa              chevrolet impala
# 7            8    usa             plymouth fury iii
# 8            8    usa              pontiac catalina
# 13           8    usa       buick estate wagon (sw)
# 43           8    usa      ford country squire (sw)
# 44           8    usa           pontiac safari (sw)
# 67           8    usa               mercury marquis
# 68           8    usa          buick lesabre custom
# 90           8    usa      mercury marquis brougham
# 94           8    usa  chrysler new yorker brougham
# 95           8    usa      buick electra 225 custom
# 105          8    usa        plymouth custom suburb
# 137          8    usa      buick century luxus (sw)
# 139          8    usa         ford gran torino (sw)
# 156          8    usa              pontiac catalina
# 159          8    usa                      ford ltd
